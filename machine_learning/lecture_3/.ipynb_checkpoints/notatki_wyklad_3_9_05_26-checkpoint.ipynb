# %% [markdown]
# # Notatki do wykładu 3:

# %% [markdown]
# Zapomniałem zwrócić uwagę na coś ważnego, wrzucam zrzuty notebooka:
#
# obrazobraz
#
# Zwróćcie uwagę, że mamy dwa rodzaje y (ygreków). Jeden z \hat a drugi z \bar (trójkącik - kreska). Jeden dotyczy regresji, a drugi dotyczy średniej. To jest ważne, bo w sposób bezpośredni tłumaczy jak dokonujemy dopasowania w modelu. Drugie to zwyczajna (\bar - kreska) średnia, ale też jest ważna, bo z obu wyciągamy potem istotne miary do opisu modelu lub danych.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Do pamiętania i przerobienia na zajęciach (ćwiczenia/wykład):
# - regresja logistyczna (odds/prob zrobione z grubsza) - wspomniane tylko
# - regresja (GLM?) ! notebook 08! (nie zrobiliśmy GLM)
# -

# %% [markdown]
# ## Do zrobienia
# Tematy do zrobienia:
# 1. LDA - wykład - i inne?
# 2. drzewa decyzyjne, lasy losowe, xgboost - kolejny wykład?
# 3. PCA/KNN/Manifold (t-SNE / UMAP)learning/SVM - kolejny wykład?

# %% [markdown]
# 1. Zastanowić się, które rzeczy z matematyki poruszyć przy kolejnych tematach, ale dopiero po tym jak wybiorę temat, aby krótko opowiedzieć intuicję, a potem przejść do konkretów.
# 2. Kolejny wykład propozycja:
#     - drzewa decyzyjne,
#     - lasy losowe,
#     - xgboost
# 3. Kolejny wykład propozycja:
#     - PCA/
#     - KNN/
#     - Manifold (t-SNE / UMAP)learning/
#     - SVM - kolejny wykład?

# %% [markdown]
# ### Do zastanowienia teraz (ważne!):
# Co będzie  teraz lepiej zrobić - płynniej z tym co udało się przerobić?
