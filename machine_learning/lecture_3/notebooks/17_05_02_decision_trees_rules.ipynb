# %% [markdown]
# # 02 — Drzewa decyzyjne: reguły zamiast geometrii
#
# Pytanie: **czy da się klasyfikować prostymi regułami if/else?**
#
# Drzewa są dobrym kontrastem dla KNN: nie potrzebują odległości ani skalowania w takim samym sensie.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ml_teaching_pack import make_dataset, list_datasets, curriculum_table
from ml_teaching_pack import split_scale, pca_project, add_radial_feature
from ml_teaching_pack import get_model, model_library
from ml_teaching_pack import compare_models, run_basic_experiment
from ml_teaching_pack.visualization import plot_2d_points, plot_decision_boundary_2d, plot_pca_variance, plot_pca_scatter

# %%
ds = make_dataset('moons', n_samples=500, random_state=7)
X, y = ds.as_xy()
split = split_scale(X, y, scale=False, random_state=42)

# %%
for name in ['tree', 'tree_deep']:
    model = get_model(name, random_state=42)
    model.fit(split.X_train, split.y_train)
    plot_decision_boundary_2d(model, split.X_train, split.y_train, title=name)
    plt.show()

# %% [markdown]
# ## Drzewa vs modele geometryczne

# %%
models = model_library('full')
# Dla porównania wszystkie modele dostają skalowane dane; drzewa tego nie wymagają, ale nie szkodzi to ich logice splitów.
split_scaled = split_scale(X, y, scale=True, random_state=42)
compare_models(models, split_scaled.X_train, split_scaled.X_test, split_scaled.y_train, split_scaled.y_test)
