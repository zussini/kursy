# %% [markdown]
# # 05 — Ensemble i XGBoost opcjonalnie
#
# Pytanie: **co daje wiele słabszych drzew zamiast jednego?**
#
# XGBoost nie jest dobrym pierwszym modelem. Najpierw: pojedyncze drzewo, Random Forest, Gradient Boosting. Dopiero potem XGBoost jako mocniejszy wariant praktyczny.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ml_teaching_pack import make_dataset, list_datasets, curriculum_table
from ml_teaching_pack import split_scale, pca_project, add_radial_feature
from ml_teaching_pack import get_model, model_library
from ml_teaching_pack import compare_models, run_basic_experiment
from ml_teaching_pack.visualization import plot_2d_points, plot_decision_boundary_2d, plot_pca_variance, plot_pca_scatter

# %%
ds = make_dataset('breast_cancer')
X, y = ds.as_xy()
split = split_scale(X, y, scale=False, random_state=42)
models = model_library('trees')
compare_models(models, split.X_train, split.X_test, split.y_train, split.y_test)

# %% [markdown]
# ## XGBoost jako opcja

# %%
try:
    xgb = get_model('xgboost_optional', random_state=42)
    xgb.fit(split.X_train, split.y_train)
    from ml_teaching_pack.evaluation import evaluate_classifier
    print(evaluate_classifier(xgb, split.X_test, split.y_test))
except ImportError as e:
    print(e)

# %% [markdown]
# ## Porównanie z modelami geometrycznymi
#
# Na danych tablicowych bardzo często modele drzewiaste są silnym punktem odniesienia.

# %%
split_scaled = split_scale(X, y, scale=True, random_state=42)
compare_models(model_library('full'), split_scaled.X_train, split_scaled.X_test, split_scaled.y_train, split_scaled.y_test)
