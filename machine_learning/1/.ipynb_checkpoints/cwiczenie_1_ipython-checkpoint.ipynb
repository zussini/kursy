# %% [markdown]
# # 1. Uruchom z shell: ipython

# %% [markdown]
# ## Notebook 1.02 1.03 - przejść wspólnie przez te nb - na wykładzie przejść przez notebooki z githuba.
# - Ćwiczenie (Text Entry Shortcuts):
# Fun exercise, take this string a sort it usign Ctrl-t, sort by transpose the set :) string:fsasdfasdasdf
#
# - Pasting (1.03)
# - Input Output (1.04)
# - Shell (1.05)
# - errors - debugging (1.06)
# - timing profiling (1.07)

# %% [markdown]
# Przećwiczyć każde polecenie z tego notebooka
# Ćwiczenia ?
#
# Ćwiczenia 1.05 - potencjalnie ciekawe

# %% [markdown]
# ### Do wykonania przez studentów - ćwiczenia folder: cwiczenie_1_ipython_full_pack_with_addons
