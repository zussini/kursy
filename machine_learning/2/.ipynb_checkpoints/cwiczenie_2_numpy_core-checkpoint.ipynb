# %% [markdown]
# # Zajęcia 2 — NumPy (wykład + ćwiczenia)
#
# Ten plik jest **krótką ściągą dla prowadzącego**: co jest w materiałach do serii 2 (NumPy) i jak to poprowadzić w formacie *lecture-by-notebook + exercises*.
#
# ## Założenie prowadzenia
# - **Wykład:** idziemy przez notebooki z PDSH (`02.*`) — live demo + komentarze + krótkie pytania do sali.
# - **Ćwiczenia:** studenci dostają 1 notebook z TODO + testami ✅, który odpowiada sekcjom wykładu (02.00–02.08) + bonusy.
#
# ## Gdzie co jest (foldery)
# - **Wykład:** folder `Wyklad_jvdplas_numpy/`
# - **Ćwiczenia studentów:** folder `cwiczenie_2_numpy_full_pack/`
#
# ## Notebooki wykładowe (PDSH 02.*)
# - `02.00-Introduction-to-NumPy.ipynb` — Wprowadzenie: czym jest `ndarray`, `shape`, szybkie tworzenie tablic, dlaczego NumPy.
# - `02.01-Understanding-Data-Types.ipynb` — Typy danych (`dtype`), pamięć, konsekwencje dtype (np. overflow).
# - `02.02-The-Basics-Of-NumPy-Arrays.ipynb` — Tworzenie tablic, indeksowanie i slicing, reshape, widoki vs kopie.
# - `02.03-Computation-on-arrays-ufuncs.ipynb` — Ufuncs i wektoryzacja: operacje element-wise bez pętli, stabilność numeryczna.
# - `02.04-Computation-on-arrays-aggregates.ipynb` — Agregacje i `axis=`: sum/mean/min/max, `keepdims`, typowe pułapki kształtów.
# - `02.05-Computation-on-arrays-broadcasting.ipynb` — Broadcasting: reguły dopasowania wymiarów i praktyczne wzorce (np. odległości).
# - `02.06-Boolean-Arrays-and-Masks.ipynb` — Maski boolean: filtrowanie, selekcja, modyfikacja fragmentów tablicy.
# - `02.07-Fancy-Indexing.ipynb` — Fancy indexing: selekcja wielu elementów/wierszy, powtórzenia, `np.ix_`.
# - `02.08-Sorting.ipynb` — Sortowanie: `sort/argsort`, `argpartition` (top-k) i wzorce selekcji.
# - `02.09-Structured-Data-NumPy.ipynb` — Structured arrays: pola i typy złożone (rzadziej niż Pandas, ale warto znać).
#
# ## Notebooki ćwiczeniowe (studenci)
# - `cwiczenie_2_numpy_full_pack/cwiczenie_2_numpy_student_exercises.ipynb` — główny zestaw ćwiczeń (02.00–02.08 + bonusy ⭐), TODO + testy ✅.
# - `cwiczenie_2_numpy_full_pack/cwiczenie_2_numpy_student_exercises_done.ipynb` — wersja referencyjna (do publikacji po terminie).
#
# ## Wskazówki do prowadzenia (mini-scenariusz wykładu)
# - **Najpierw nawyki:** na każdym slajdzie/demontracji pytaj o `shape`, `dtype`, `axis` (to ma wejść w krew).
# - **Powtarzaj 3 rzeczy wiele razy:**
#   1) *bez pętli* (ufuncs), 2) `axis=` + `keepdims=`, 3) broadcasting w 2–3 wariantach.
# - **Minimalny rdzeń na wykładzie (jeśli brak czasu):** 02.00 → 02.05 (reszta jako reading + ćwiczenia).
# - **Typowe pułapki, które warto pokazać live:**
#   - view vs copy (slicing vs fancy indexing),
#   - `axis=0` vs `axis=1` (błędy w standaryzacji),
#   - broadcasting mismatch (dlaczego `(n, d)` i `(d,)` działa, a inne nie).
#
# ## Wskazówki do ćwiczeń (co sprawdzać przy oddaniu)
# - Czy student rozwiązał zadania **bez pętli** tam, gdzie to wymagane.
# - Czy testy `✅` przechodzą (to jest kryterium minimalne).
# - Czy odpowiedzi tekstowe (overflow, view/copy) są sensowne (min. kilka zdań).

# %%
# (opcjonalnie) miejsce na Twoje notatki / komendy do uruchomienia
