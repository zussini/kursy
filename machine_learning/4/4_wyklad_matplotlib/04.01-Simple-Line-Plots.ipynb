# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="figures/PDSH-cover-small.png">
#
# *This notebook contains an excerpt from the [Python Data Science Handbook](http://shop.oreilly.com/product/0636920034919.do) by Jake VanderPlas; the content is available [on GitHub](https://github.com/jakevdp/PythonDataScienceHandbook).*
#
# *The text is released under the [CC-BY-NC-ND license](https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode), and code is released under the [MIT license](https://opensource.org/licenses/MIT). If you find this content useful, please consider supporting the work by [buying the book](http://shop.oreilly.com/product/0636920034919.do)!*

# %% [markdown]
# <!--NAVIGATION-->
# < [Visualization with Matplotlib](04.00-Introduction-To-Matplotlib.ipynb) | [Contents](Index.ipynb) | [Simple Scatter Plots](04.02-Simple-Scatter-Plots.ipynb) >
#
# <a href="https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.01-Simple-Line-Plots.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %% [markdown]
# # Simple Line Plots

# %% [markdown]
# Perhaps the simplest of all plots is the visualization of a single function $y = f(x)$.
# Here we will take a first look at creating a simple plot of this type.
# As with all the following sections, we'll start by setting up the notebook for plotting and  importing the packages we will use:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
# Out:
# /tmp/ipykernel_1533425/3518078781.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# !pip install ipympl
# Out:
# Requirement already satisfied: ipympl in /home/piotr/anaconda3/lib/python3.8/site-packages (0.9.3)
# Requirement already satisfied: ipython<9 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipympl) (7.26.0)
# Requirement already satisfied: numpy in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipympl) (1.24.4)
# Requirement already satisfied: ipython-genutils in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipympl) (9.5.0)
# Requirement already satisfied: traitlets<6 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipympl) (5.9.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipympl) (7.6.3)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipympl) (3.7.5)
# Requirement already satisfied: setuptools>=18.5 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (52.0.0.post20210125)
# Requirement already satisfied: jedi>=0.16 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.17.2)
# Requirement already satisfied: decorator in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (5.0.9)
# Requirement already satisfied: pickleshare in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (3.0.17)
# Requirement already satisfied: pygments in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (2.10.0)
# Requirement already satisfied: backcall in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/piotr/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/piotr/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/piotr/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/piotr/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/piotr/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (6.1.1)
# Requirement already satisfied: six in /home/piotr/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib<4,>=3.4.0->ipympl) (3.5.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.4.1)
# Requirement already satisfied: jupyter-client<8.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.4.9)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/piotr/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.3.3)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/piotr/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.23.0)
# Requirement already satisfied: jupyter-core in /home/piotr/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (5.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/piotr/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /home/piotr/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/piotr/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/piotr/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/piotr/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /home/piotr/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/piotr/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.20.1)
# Requirement already satisfied: entrypoints in /home/piotr/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.3)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /home/piotr/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.8)
# Requirement already satisfied: pyzmq>=23.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (25.1.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/piotr/anaconda3/lib/python3.8/site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (3.10.0)
# Requirement already satisfied: jinja2 in /home/piotr/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.2)
# Requirement already satisfied: argon2-cffi in /home/piotr/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (20.1.0)
# Requirement already satisfied: nbconvert in /home/piotr/.local/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (7.3.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/piotr/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.9.4)
# Requirement already satisfied: prometheus-client in /home/piotr/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.21.1)
# Requirement already satisfied: cffi>=1.0.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.14.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/piotr/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.9.3)
# Requirement already satisfied: bleach in /home/piotr/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.0.0)
# Requirement already satisfied: defusedxml in /home/piotr/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/piotr/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.6.0)
# Requirement already satisfied: jupyterlab-pygments in /home/piotr/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/piotr/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /home/piotr/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/piotr/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.4.3)
# Requirement already satisfied: tinycss2 in /home/piotr/.local/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.2.1)
# Requirement already satisfied: pycparser in /home/piotr/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.20)
# Requirement already satisfied: async-generator in /home/piotr/anaconda3/lib/python3.8/site-packages (from nbclient>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.10)
# Requirement already satisfied: soupsieve>1.2 in /home/piotr/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.2.1)
# Requirement already satisfied: webencodings in /home/piotr/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#%matplotlib widget
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

t = np.linspace(0, 10, 200)
x = np.sin(t)
y = np.cos(t)
z = t

ax.plot(x, y, z)
plt.show()

# %% [markdown]
# For all Matplotlib plots, we start by creating a figure and an axes.
# In their simplest form, a figure and axes can be created as follows:

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# In Matplotlib, the *figure* (an instance of the class ``plt.Figure``) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels.
# The *axes* (an instance of the class ``plt.Axes``) is what we see above: a bounding box with ticks and labels, which will eventually contain the plot elements that make up our visualization.
# Throughout this book, we'll commonly use the variable name ``fig`` to refer to a figure instance, and ``ax`` to refer to an axes instance or group of axes instances.
#
# Once we have created an axes, we can use the ``ax.plot`` function to plot some data. Let's start with a simple sinusoid:

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %% [markdown]
# Alternatively, we can use the pylab interface and let the figure and axes be created for us in the background
# (see [Two Interfaces for the Price of One](04.00-Introduction-To-Matplotlib.ipynb#Two-Interfaces-for-the-Price-of-One) for a discussion of these two interfaces):

# %%
plt.plot(x, np.sin(x));

# %% [markdown]
# If we want to create a single figure with multiple lines, we can simply call the ``plot`` function multiple times:

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# That's all there is to plotting simple functions in Matplotlib!
# We'll now dive into some more details about how to control the appearance of the axes and lines.

# %% [markdown]
# ## Adjusting the Plot: Line Colors and Styles

# %% [markdown]
# The first adjustment you might wish to make to a plot is to control the line colors and styles.
# The ``plt.plot()`` function takes additional arguments that can be used to specify these.
# To adjust the color, you can use the ``color`` keyword, which accepts a string argument representing virtually any imaginable color.
# The color can be specified in a variety of ways:

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %% [markdown]
# If no color is specified, Matplotlib will automatically cycle through a set of default colors for multiple lines.
#
# Similarly, the line style can be adjusted using the ``linestyle`` keyword:

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# If you would like to be extremely terse, these ``linestyle`` and ``color`` codes can be combined into a single non-keyword argument to the ``plt.plot()`` function:

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# These single-character color codes reflect the standard abbreviations in the RGB (Red/Green/Blue) and CMYK (Cyan/Magenta/Yellow/blacK) color systems, commonly used for digital color graphics.
#
# There are many other keyword arguments that can be used to fine-tune the appearance of the plot; for more details, I'd suggest viewing the docstring of the ``plt.plot()`` function using IPython's help tools (See [Help and Documentation in IPython](01.01-Help-And-Documentation.ipynb)).

# %% [markdown]
# ## Adjusting the Plot: Axes Limits
#
# Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control.
# The most basic way to adjust axis limits is to use the ``plt.xlim()`` and ``plt.ylim()`` methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %% [markdown]
# If for some reason you'd like either axis to be displayed in reverse, you can simply reverse the order of the arguments:

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %% [markdown]
# A useful related method is ``plt.axis()`` (note here the potential confusion between *axes* with an *e*, and *axis* with an *i*).
# The ``plt.axis()`` method allows you to set the ``x`` and ``y`` limits with a single call, by passing a list which specifies ``[xmin, xmax, ymin, ymax]``:

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# The ``plt.axis()`` method goes even beyond this, allowing you to do things like automatically tighten the bounds around the current plot:

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %% [markdown]
# It allows even higher-level specifications, such as ensuring an equal aspect ratio so that on your screen, one unit in ``x`` is equal to one unit in ``y``:

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# For more information on axis limits and the other capabilities of the ``plt.axis`` method, refer to the ``plt.axis`` docstring.

# %% [markdown]
# ## Labeling Plots
#
# As the last piece of this section, we'll briefly look at the labeling of plots: titles, axis labels, and simple legends.
#
# Titles and axis labels are the simplest such labels—there are methods that can be used to quickly set them:

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# The position, size, and style of these labels can be adjusted using optional arguments to the function.
# For more information, see the Matplotlib documentation and the docstrings of each of these functions.

# %% [markdown]
# When multiple lines are being shown within a single axes, it can be useful to create a plot legend that labels each line type.
# Again, Matplotlib has a built-in way of quickly creating such a legend.
# It is done via the (you guessed it) ``plt.legend()`` method.
# Though there are several valid ways of using this, I find it easiest to specify the label of each line using the ``label`` keyword of the plot function:

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# As you can see, the ``plt.legend()`` function keeps track of the line style and color, and matches these with the correct label.
# More information on specifying and formatting plot legends can be found in the ``plt.legend`` docstring; additionally, we will cover some more advanced legend options in [Customizing Plot Legends](04.06-Customizing-Legends.ipynb).

# %% [markdown]
# ## Aside: Matplotlib Gotchas
#
# While most ``plt`` functions translate directly to ``ax`` methods (such as ``plt.plot()`` → ``ax.plot()``, ``plt.legend()`` → ``ax.legend()``, etc.), this is not the case for all commands.
# In particular, functions to set limits, labels, and titles are slightly modified.
# For transitioning between MATLAB-style functions and object-oriented methods, make the following changes:
#
# - ``plt.xlabel()``  → ``ax.set_xlabel()``
# - ``plt.ylabel()`` → ``ax.set_ylabel()``
# - ``plt.xlim()``  → ``ax.set_xlim()``
# - ``plt.ylim()`` → ``ax.set_ylim()``
# - ``plt.title()`` → ``ax.set_title()``
#
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the ``ax.set()`` method to set all these properties at once:

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# <!--NAVIGATION-->
# < [Visualization with Matplotlib](04.00-Introduction-To-Matplotlib.ipynb) | [Contents](Index.ipynb) | [Simple Scatter Plots](04.02-Simple-Scatter-Plots.ipynb) >
#
# <a href="https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.01-Simple-Line-Plots.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>
