# %% [markdown]
# # Zajecia 4 - Matplotlib (wyklad + cwiczenia)
#
# Podobnie jak w 3, wyklad pozostaje bez zmian; ten notebook tylko spina czesc praktyczna.
# Cwiczenia korzystaja z tych samych danych syntetycznych, aby plotting byl naturalna kontynuacja
# pracy z NumPy i Pandas.

# %% [markdown]
# ## Sekcje, ktore realnie wykorzystujemy w cwiczeniach
#
# - 04.01 - Simple Line Plots
# - 04.02 - Simple Scatter Plots
# - 04.03 - Errorbars
# - 04.05 - Histograms and Binnings
# - 04.07 - Customizing Colorbars
# - 04.08 - Multiple Subplots
# - 04.09 - Text and Annotation
# - 04.10 - Customizing Ticks
# - 04.11 - Settings and Stylesheets

# %% [markdown]
# ## Material roboczy
#
# Glowny notebook:
# **`cwiczenie_4_matplotlib_student_exercises.ipynb`**
#
# Wspolny generator danych:
# **`projekt_1_4_bikeshare_core.py`**

# %%
# (opcjonalnie) miejsce na Twoje notatki / komendy do uruchomienia
