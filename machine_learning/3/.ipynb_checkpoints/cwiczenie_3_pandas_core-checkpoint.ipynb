# %% [markdown]
# # Zajecia 3 - Pandas (wyklad + cwiczenia)
#
# Ten notebook jest "core-em" organizacyjnym, analogicznie do czesci 1 i 2.
# Wyklad pozostaje bez zmian; tutaj jedynie spinamy tematy i kierujemy do zestawu cwiczen.

# %% [markdown]
# ## Sekcje wykladu, do ktorych podpiete sa cwiczenia
#
# - 03.01 - Introducing Pandas Objects
# - 03.02 - Data Indexing and Selection
# - 03.03 - Operations in Pandas
# - 03.04 - Missing Values
# - 03.05 - Hierarchical Indexing
# - 03.06 - Concat and Append
# - 03.07 - Merge and Join
# - 03.08 - Aggregation and Grouping
# - 03.09 - Pivot Tables
# - 03.10 - Working With Strings
# - 03.11 - Working with Time Series
# - 03.12 - Performance: `eval()` i `query()`

# %% [markdown]
# ## Material roboczy
#
# Glowny notebook ze student exercises:
# **`cwiczenie_3_pandas_student_exercises.ipynb`**
#
# Wspolny generator danych i helpery do projektu dla wykładów 1-4:
# **`projekt_1_4_bikeshare_core.py`**

# %%
# (opcjonalnie) miejsce na Twoje notatki / komendy do uruchomienia
